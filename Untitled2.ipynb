# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import test_func as tf
# %matplotlib inline

# %%
files=glob.glob('train/*.csv')
data_list=[]

for file in files:
    data_list.append(pd.read_csv(file,index_col=0))
    
df=pd.concat(data_list)
# Out:
# C:\Users\fujir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
def data_pre(df):
    df=df.drop(['市区町村名'],axis=1)

    df=df.drop(['種類'],axis=1)

    nonnull_list=[]

    for col in df.columns:
        nonnull=df[col].count()
        if nonnull==0:
            nonnull_list.append(col)
    df=df.drop(nonnull_list,axis=1)   

    dis={
        '30分?60分':45,
        '1H?1H30':75,
        '1H30?2H':105,
        '2H?':120
    }
    df['最寄駅：距離（分）']=df['最寄駅：距離（分）'].replace(dis).astype(float)

    df['面積（㎡）']=df['面積（㎡）'].replace({'2000㎡以上':2000}).astype(float)

    y_list={}
    for i in df['建築年'].value_counts().keys():
        if '平成' in i:
            num=float(i.split('平成')[1].split('年')[0])
            year=33-num
        if '令和' in i:
            num=float(i.split('令和')[1].split('年')[0])
            year=3-num 
        if '昭和' in i:
            num=float(i.split('昭和')[1].split('年')[0])
            year=96-num     
        y_list[i]=year
        y_list['戦前']=76
    df['建築年']=df['建築年'].replace(y_list)   

    year={
        '年第１四半期':'.25',
        '年第２四半期':'.50',
        '年第３四半期':'.75',
        '年第４四半期':'.99',
    }
    year_list={}
    for i in df['取引時点'].value_counts().keys():
        for k, j in year.items():
            if k in i:
                year_rep=i.replace(k, j)
        year_list[i]=year_rep    
    df['取引時点']=df['取引時点'].replace(year_list).astype(float)
    
    for col in  ["都道府県名", "地区名", "最寄駅：名称", "間取り", "建物の構造", "用途", "今後の利用目的", "都市計画", "改装", "取引の事情等"]:
        df[col]=df[col].astype('category')
    return df

# %%
df=data_pre(df)

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error as mae

# %%
df_train,df_val=train_test_split(df,test_size=0.4,random_state=365)

# %%
col='取引価格（総額）_log'

train_inputs=df_train.drop([col],axis=1)
train_targets=df_train[col]

val_inputs=df_val.drop([col],axis=1)
val_targets=df_val[col]

train_dataset=lgb.Dataset(train_inputs,train_targets)
val_dataset=lgb.Dataset(val_inputs,val_targets)

params={
    'objective':'regression',
    'metrics':'mae'
}

# %%
model=lgb.train(params,train_dataset,valid_sets=val_dataset,num_boost_round=1000,early_stopping_rounds=100)
# Out:
# C:\Users\fujir\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028497 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11689
# [LightGBM] [Info] Number of data points in the train set: 382410, number of used features: 17
# C:\Users\fujir\anaconda3\lib\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# ...

# %%
y_hat=model.predict(val_inputs)
mae(y_hat,val_targets)
# Out:
# 0.07832986636490824

# %%
df_test=pd.read_csv('test.csv',index_col=0)

# %%
df_test=data_pre(df_test)

# %%
predict=model.predict(df_test)
df_test[col]=predict

# %%
pd.DataFrame(model.feature_importance(),index=val_inputs.columns,columns=['importance']).sort_values(by='importance',ascending=False)
# Out:
#            importance
# 地区名              7694
# 最寄駅：名称           6193
# 建築年              3766
# 取引時点             3396
# 面積（㎡）            2273
# 最寄駅：距離（分）        2100
# 間取り               970
# 市区町村コード           895
# 改装                566
# 都道府県名             557
# 容積率（％）            517
# 都市計画              400
# 建ぺい率（％）           200
# 取引の事情等            145
# 建物の構造             118
# 今後の利用目的           105
# 用途                105
